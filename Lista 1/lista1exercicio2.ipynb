# %%
import pandas as pd

# 2) Crie uma série com os dias da semana como índices e as temperaturas correspondentes como valores.
dias_da_semana = ['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado', 'Domingo']
temperaturas = [22, 24, 21, 23, 25, 20, 22]

serie_temperaturas = pd.Series(temperaturas, index=dias_da_semana)

print(serie_temperaturas)
# Out:
# Segunda    22
# Terça      24
# Quarta     21
# Quinta     23
# Sexta      25
# Sábado     20
# Domingo    22
# dtype: int64
