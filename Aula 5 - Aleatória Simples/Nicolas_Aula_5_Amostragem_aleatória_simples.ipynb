# %%
import pandas as pd
import random
import numpy as np

# %%
dataset = pd.read_csv('census.csv', delimiter=';')

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
dataset.tail()
# Out:
#        age      workclass  final-weight    education  education-num  \
# 32556   27        Private        257302   Assoc-acdm             12
# 32557   40        Private        154374      HS-grad              9
# 32558   58        Private        151910      HS-grad              9
# 32559   22        Private        201490      HS-grad              9
# 32560   52   Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# 32556             0             0             38   United-States   <=50K
# 32557             0             0             40   United-States    >50K
# 32558             0             0             40   United-States   <=50K
# 32559             0             0             20   United-States   <=50K
# 32560         15024             0             40   United-States    >50K

# %%
df_amostra_aleatoria_simples = dataset.sample(n = 100)

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age   workclass  final-weight   education  education-num  \
# 28270   63     Private         76860   Bachelors             13
# 32228   40     Private        177905   Assoc-voc             11
# 22956   30   State-gov        137613     Masters             14
# 28224   53     Private        250034   Bachelors             13
# 11301   36     Private         20507     HS-grad              9
#
#             marital-status        occupation relationship  \
# 28270   Married-civ-spouse   Protective-serv      Husband
# 32228   Married-civ-spouse   Exec-managerial      Husband
# 22956   Married-civ-spouse    Prof-specialty      Husband
# 28224   Married-civ-spouse   Exec-managerial      Husband
# 11301   Married-civ-spouse      Craft-repair      Husband
#
#                       race    sex  capital-gain  capital-loos  hour-per-week  \
# 28270   Asian-Pac-Islander   Male             0             0             40
# 32228                White   Male          7688             0             44
# 22956   Asian-Pac-Islander   Male             0             0             20
# 28224                Black   Male             0             0             50
# 11301                White   Male          7688             0             50
#
#        native-country  income
# 28270     Philippines    >50K
# 32228   United-States    >50K
# 22956          Taiwan   <=50K
# 28224   United-States    >50K
# 11301   United-States    >50K

# %%
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples = dataset.sample(n = 100, random_state = 1)

# %%
def amostragem_aleatória_simples(dataset, amostras):
    return dataset.sample(n = amostras)

# %%
df_amostra_aleatoria_simples= amostragem_aleatória_simples(dataset, 100)
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age workclass  final-weight   education  education-num  \
# 20019   61   Private        101500   Assoc-voc             11
# 19248   23   Private        139187        11th              7
# 9809    50   Private         34233     HS-grad              9
# 4506    35   Private        181020     HS-grad              9
# 5552    35   Private        112160     HS-grad              9
#
#             marital-status          occupation relationship    race    sex  \
# 20019   Married-civ-spouse        Adm-clerical      Husband   White   Male
# 19248        Never-married   Handlers-cleaners    Own-child   White   Male
# 9809    Married-civ-spouse     Farming-fishing      Husband   White   Male
# 4506         Never-married   Handlers-cleaners    Own-child   White   Male
# 5552    Married-civ-spouse               Sales      Husband   White   Male
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# 20019             0             0             40   United-States   <=50K
# 19248             0             0             50   United-States   <=50K
# 9809              0             0             50   United-States   <=50K
# 4506              0             0             60   United-States   <=50K
# 5552              0             0             40   United-States   <=50K
